# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import asyncio
import json
import aiohttp
from understat import Understat
import nest_asyncio

# %%
nest_asyncio.apply()
async def all_understat_players():
    async with aiohttp.ClientSession() as session:
        understat = Understat(session)
        players = await understat.get_league_players(
            "epl",
            2022,
        )
        return json.dumps(players)

players = asyncio.run(all_understat_players())
players = json.loads(players)

# %%
players
# Out:
# [{'id': '8260',
#   'player_name': 'Erling Haaland',
#   'games': '11',
#   'time': '941',
#   'goals': '17',
#   'xG': '11.791812658309937',
#   'assists': '3',
#   'xA': '2.7509437054395676',
#   'shots': '47',
#   'key_passes': '11',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F',
#   'team_title': 'Manchester City',
#   'npg': '15',
#   'npxG': '10.26947483420372',
#   'xGChain': '11.118985623121262',
#   'xGBuildup': '0.7943455772474408'},
#  {'id': '647',
#   'player_name': 'Harry Kane',
#   'games': '12',
#   'time': '1074',
#   'goals': '10',
#   'xG': '9.32776327431202',
#   'assists': '1',
#   'xA': '2.9637172892689705',
#   'shots': '47',
#   'key_passes': '24',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F',
#   'team_title': 'Tottenham',
#   'npg': '8',
#   'npxG': '7.044256746768951',
#   'xGChain': '8.222224488854408',
#   'xGBuildup': '1.282837226986885'},
#  {'id': '773',
#   'player_name': 'Aleksandar Mitrovic',
#   'games': '11',
#   'time': '932',
#   'goals': '9',
#   'xG': '8.030353024601936',
#   'assists': '0',
#   'xA': '1.1320357620716095',
#   'shots': '46',
#   'key_passes': '8',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F',
#   'team_title': 'Fulham',
#   'npg': '6',
#   'npxG': '4.985677748918533',
#   'xGChain': '6.109406538307667',
#   'xGBuildup': '1.5657426305115223'},
#  {'id': '998',
#   'player_name': 'Ivan Toney',
#   'games': '12',
#   'time': '1080',
#   'goals': '8',
#   'xG': '7.4743891903199255',
#   'assists': '2',
#   'xA': '2.2233567759394646',
#   'shots': '32',
#   'key_passes': '14',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'F',
#   'team_title': 'Brentford',
#   'npg': '5',
#   'npxG': '5.190882647875696',
#   'xGChain': '6.352061927318573',
#   'xGBuildup': '1.8948282897472382'},
#  {'id': '482',
#   'player_name': 'Roberto Firmino',
#   'games': '10',
#   'time': '706',
#   'goals': '6',
#   'xG': '5.394283227622509',
#   'assists': '3',
#   'xA': '2.019450033083558',
#   'shots': '26',
#   'key_passes': '13',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Liverpool',
#   'npg': '6',
#   'npxG': '5.394283227622509',
#   'xGChain': '7.279561562463641',
#   'xGBuildup': '2.9644855726510286'},
#  {'id': '6055',
#   'player_name': 'Phil Foden',
#   'games': '11',
#   'time': '793',
#   'goals': '6',
#   'xG': '3.3744489178061485',
#   'assists': '4',
#   'xA': '2.57360771112144',
#   'shots': '20',
#   'key_passes': '19',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Manchester City',
#   'npg': '6',
#   'npxG': '3.3744489178061485',
#   'xGChain': '9.385159730911255',
#   'xGBuildup': '4.551174681633711'},
#  {'id': '6818',
#   'player_name': 'James Maddison',
#   'games': '10',
#   'time': '896',
#   'goals': '6',
#   'xG': '1.7558306157588959',
#   'assists': '2',
#   'xA': '1.0945376604795456',
#   'shots': '30',
#   'key_passes': '22',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Leicester',
#   'npg': '6',
#   'npxG': '1.7558306157588959',
#   'xGChain': '3.4882569685578346',
#   'xGBuildup': '1.7409977167844772'},
#  {'id': '7420',
#   'player_name': 'Miguel Almirón',
#   'games': '12',
#   'time': '1027',
#   'goals': '6',
#   'xG': '4.457711782306433',
#   'assists': '0',
#   'xA': '0.5967541188001633',
#   'shots': '31',
#   'key_passes': '7',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F',
#   'team_title': 'Newcastle United',
#   'npg': '6',
#   'npxG': '4.457711782306433',
#   'xGChain': '5.385970555245876',
#   'xGBuildup': '1.1900529488921165'},
#  {'id': '7698',
#   'player_name': 'Leandro Trossard',
#   'games': '11',
#   'time': '937',
#   'goals': '6',
#   'xG': '3.670556917786598',
#   'assists': '1',
#   'xA': '1.1182364542037249',
#   'shots': '28',
#   'key_passes': '17',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D F M',
#   'team_title': 'Brighton',
#   'npg': '6',
#   'npxG': '3.670556917786598',
#   'xGChain': '7.00836743414402',
#   'xGBuildup': '2.7793546561151743'},
#  {'id': '522',
#   'player_name': 'Wilfried Zaha',
#   'games': '10',
#   'time': '883',
#   'goals': '5',
#   'xG': '3.947492066770792',
#   'assists': '1',
#   'xA': '1.3110596295446157',
#   'shots': '27',
#   'key_passes': '11',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F M',
#   'team_title': 'Crystal Palace',
#   'npg': '5',
#   'npxG': '3.1863232292234898',
#   'xGChain': '5.5978048369288445',
#   'xGBuildup': '2.0220478177070618'},
#  {'id': '2381',
#   'player_name': 'Rodrigo',
#   'games': '10',
#   'time': '681',
#   'goals': '5',
#   'xG': '3.817358087748289',
#   'assists': '1',
#   'xA': '1.5805326765403152',
#   'shots': '31',
#   'key_passes': '8',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Leeds',
#   'npg': '5',
#   'npxG': '3.817358087748289',
#   'xGChain': '4.611000947654247',
#   'xGBuildup': '0.5786900790408254'},
#  {'id': '5543',
#   'player_name': 'Gabriel Jesus',
#   'games': '11',
#   'time': '967',
#   'goals': '5',
#   'xG': '7.488491829484701',
#   'assists': '3',
#   'xA': '1.8340234085917473',
#   'shots': '35',
#   'key_passes': '16',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'F',
#   'team_title': 'Arsenal',
#   'npg': '5',
#   'npxG': '7.488491829484701',
#   'xGChain': '9.885371565818787',
#   'xGBuildup': '2.6571745183318853'},
#  {'id': '468',
#   'player_name': 'Callum Wilson',
#   'games': '8',
#   'time': '669',
#   'goals': '4',
#   'xG': '5.123193100094795',
#   'assists': '1',
#   'xA': '0.8603344578295946',
#   'shots': '22',
#   'key_passes': '8',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F',
#   'team_title': 'Newcastle United',
#   'npg': '4',
#   'npxG': '5.123193100094795',
#   'xGChain': '4.279784768819809',
#   'xGBuildup': '0.3018884100019932'},
#  {'id': '6681',
#   'player_name': 'Harvey Barnes',
#   'games': '10',
#   'time': '830',
#   'goals': '4',
#   'xG': '2.3420830741524696',
#   'assists': '0',
#   'xA': '0.3097148612141609',
#   'shots': '23',
#   'key_passes': '4',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Leicester',
#   'npg': '4',
#   'npxG': '2.3420830741524696',
#   'xGChain': '4.520510166883469',
#   'xGBuildup': '1.887376181781292'},
#  {'id': '7322',
#   'player_name': 'Bukayo Saka',
#   'games': '11',
#   'time': '981',
#   'goals': '4',
#   'xG': '4.1172291077673435',
#   'assists': '4',
#   'xA': '1.1442773379385471',
#   'shots': '27',
#   'key_passes': '20',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F M',
#   'team_title': 'Arsenal',
#   'npg': '3',
#   'npxG': '3.3560602702200413',
#   'xGChain': '6.79095946252346',
#   'xGBuildup': '2.903368130326271'},
#  {'id': '7752',
#   'player_name': 'Gabriel Martinelli',
#   'games': '11',
#   'time': '950',
#   'goals': '4',
#   'xG': '3.2143460251390934',
#   'assists': '2',
#   'xA': '3.4658465329557657',
#   'shots': '28',
#   'key_passes': '21',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F M',
#   'team_title': 'Arsenal',
#   'npg': '4',
#   'npxG': '3.2143460251390934',
#   'xGChain': '8.04932114481926',
#   'xGBuildup': '2.869172904640436'},
#  {'id': '8379',
#   'player_name': 'Alexis Mac Allister',
#   'games': '11',
#   'time': '990',
#   'goals': '4',
#   'xG': '2.7067082514986396',
#   'assists': '0',
#   'xA': '0.23433474078774452',
#   'shots': '20',
#   'key_passes': '6',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Brighton',
#   'npg': '1',
#   'npxG': '0.423201703466475',
#   'xGChain': '5.736797038465738',
#   'xGBuildup': '5.2881835754960775'},
#  {'id': '204',
#   'player_name': 'Granit Xhaka',
#   'games': '11',
#   'time': '990',
#   'goals': '3',
#   'xG': '1.7447387799620628',
#   'assists': '3',
#   'xA': '1.487326007336378',
#   'shots': '13',
#   'key_passes': '17',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Arsenal',
#   'npg': '3',
#   'npxG': '1.7447387799620628',
#   'xGChain': '6.078576743602753',
#   'xGBuildup': '3.8566971886903048'},
#  {'id': '239',
#   'player_name': 'Pascal Groß',
#   'games': '11',
#   'time': '937',
#   'goals': '3',
#   'xG': '2.727301210165024',
#   'assists': '2',
#   'xA': '3.879538344219327',
#   'shots': '15',
#   'key_passes': '25',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D F M',
#   'team_title': 'Brighton',
#   'npg': '3',
#   'npxG': '2.727301210165024',
#   'xGChain': '7.799980381503701',
#   'xGBuildup': '2.8664254751056433'},
#  {'id': '343',
#   'player_name': 'Pierre-Emile Højbjerg',
#   'games': '11',
#   'time': '977',
#   'goals': '3',
#   'xG': '0.5063363742083311',
#   'assists': '1',
#   'xA': '1.1587440138682723',
#   'shots': '10',
#   'key_passes': '10',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Tottenham',
#   'npg': '3',
#   'npxG': '0.5063363742083311',
#   'xGChain': '4.073096353560686',
#   'xGBuildup': '2.6064149886369705'},
#  {'id': '453',
#   'player_name': 'Son Heung-Min',
#   'games': '12',
#   'time': '959',
#   'goals': '3',
#   'xG': '3.2851098999381065',
#   'assists': '2',
#   'xA': '1.5850658332929015',
#   'shots': '33',
#   'key_passes': '22',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Tottenham',
#   'npg': '3',
#   'npxG': '3.2851098999381065',
#   'xGChain': '5.824775509536266',
#   'xGBuildup': '1.9862236976623535'},
#  {'id': '556',
#   'player_name': 'Marcus Rashford',
#   'games': '11',
#   'time': '866',
#   'goals': '3',
#   'xG': '4.2098981738090515',
#   'assists': '2',
#   'xA': '1.919924696907401',
#   'shots': '25',
#   'key_passes': '9',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Manchester United',
#   'npg': '3',
#   'npxG': '4.2098981738090515',
#   'xGChain': '7.23813359066844',
#   'xGBuildup': '1.2844524942338467'},
#  {'id': '618',
#   'player_name': 'Raheem Sterling',
#   'games': '10',
#   'time': '809',
#   'goals': '3',
#   'xG': '4.088671997189522',
#   'assists': '1',
#   'xA': '1.8452078374102712',
#   'shots': '18',
#   'key_passes': '15',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D F M S',
#   'team_title': 'Chelsea',
#   'npg': '3',
#   'npxG': '4.088671997189522',
#   'xGChain': '6.268474295735359',
#   'xGBuildup': '0.5819206405431032'},
#  {'id': '986',
#   'player_name': 'Danny Ings',
#   'games': '11',
#   'time': '534',
#   'goals': '3',
#   'xG': '3.156945213675499',
#   'assists': '0',
#   'xA': '0.28026342764496803',
#   'shots': '21',
#   'key_passes': '6',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Aston Villa',
#   'npg': '2',
#   'npxG': '2.395776316523552',
#   'xGChain': '2.6017494164407253',
#   'xGBuildup': '0.13704940490424633'},
#  {'id': '1250',
#   'player_name': 'Mohamed Salah',
#   'games': '11',
#   'time': '975',
#   'goals': '3',
#   'xG': '5.3870247937738895',
#   'assists': '3',
#   'xA': '2.446579549461603',
#   'shots': '36',
#   'key_passes': '28',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F M',
#   'team_title': 'Liverpool',
#   'npg': '3',
#   'npxG': '5.3870247937738895',
#   'xGChain': '8.29196834564209',
#   'xGBuildup': '1.5397061929106712'},
#  {'id': '2517',
#   'player_name': 'Martin Odegaard',
#   'games': '10',
#   'time': '835',
#   'goals': '3',
#   'xG': '1.9117262363433838',
#   'assists': '2',
#   'xA': '2.861658848822117',
#   'shots': '23',
#   'key_passes': '19',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Arsenal',
#   'npg': '3',
#   'npxG': '1.9117262363433838',
#   'xGChain': '7.424026846885681',
#   'xGBuildup': '4.2848896458745'},
#  {'id': '6034',
#   'player_name': 'Philip Billing',
#   'games': '12',
#   'time': '906',
#   'goals': '3',
#   'xG': '0.9280644273385406',
#   'assists': '1',
#   'xA': '0.8839881122112274',
#   'shots': '8',
#   'key_passes': '9',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Bournemouth',
#   'npg': '3',
#   'npxG': '0.9280644273385406',
#   'xGChain': '2.766290370374918',
#   'xGBuildup': '1.1993317268788815'},
#  {'id': '6827',
#   'player_name': 'Bobby Reid',
#   'games': '12',
#   'time': '1057',
#   'goals': '3',
#   'xG': '2.856547676026821',
#   'assists': '1',
#   'xA': '0.5744882747530937',
#   'shots': '15',
#   'key_passes': '8',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'D M',
#   'team_title': 'Fulham',
#   'npg': '3',
#   'npxG': '2.856547676026821',
#   'xGChain': '4.5019008200615644',
#   'xGBuildup': '1.7037725243717432'},
#  {'id': '7700',
#   'player_name': 'Che Adams',
#   'games': '11',
#   'time': '826',
#   'goals': '3',
#   'xG': '2.926247011870146',
#   'assists': '1',
#   'xA': '1.2400682056322694',
#   'shots': '19',
#   'key_passes': '12',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Southampton',
#   'npg': '3',
#   'npxG': '2.926247011870146',
#   'xGChain': '4.904734384268522',
#   'xGBuildup': '1.3896886892616749'},
#  {'id': '7814',
#   'player_name': 'Taiwo Awoniyi',
#   'games': '11',
#   'time': '432',
#   'goals': '3',
#   'xG': '3.820949003100395',
#   'assists': '0',
#   'xA': '0.6826572511345148',
#   'shots': '14',
#   'key_passes': '5',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Nottingham Forest',
#   'npg': '3',
#   'npxG': '3.820949003100395',
#   'xGChain': '2.6204756889492273',
#   'xGBuildup': '0.17131400667130947'},
#  {'id': '8150',
#   'player_name': 'Anthony Gordon',
#   'games': '11',
#   'time': '874',
#   'goals': '3',
#   'xG': '2.512069173157215',
#   'assists': '0',
#   'xA': '0.5802217572927475',
#   'shots': '20',
#   'key_passes': '6',
#   'yellow_cards': '6',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Everton',
#   'npg': '3',
#   'npxG': '2.512069173157215',
#   'xGChain': '3.2568246945738792',
#   'xGBuildup': '0.6121959090232849'},
#  {'id': '9738',
#   'player_name': 'Patson Daka',
#   'games': '11',
#   'time': '480',
#   'goals': '3',
#   'xG': '1.4827978685498238',
#   'assists': '1',
#   'xA': '1.323793713003397',
#   'shots': '11',
#   'key_passes': '6',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Leicester',
#   'npg': '3',
#   'npxG': '1.4827978685498238',
#   'xGChain': '3.131240777671337',
#   'xGBuildup': '0.3246491961181164'},
#  {'id': '10408',
#   'player_name': 'Luis Díaz',
#   'games': '8',
#   'time': '612',
#   'goals': '3',
#   'xG': '2.593675196170807',
#   'assists': '2',
#   'xA': '1.439087656326592',
#   'shots': '16',
#   'key_passes': '6',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Liverpool',
#   'npg': '3',
#   'npxG': '2.593675196170807',
#   'xGChain': '6.22053524851799',
#   'xGBuildup': '2.5845453534275293'},
#  {'id': '10720',
#   'player_name': 'Darwin Núñez',
#   'games': '7',
#   'time': '346',
#   'goals': '3',
#   'xG': '4.497195553034544',
#   'assists': '1',
#   'xA': '1.0923171117901802',
#   'shots': '28',
#   'key_passes': '5',
#   'yellow_cards': '0',
#   'red_cards': '1',
#   'position': 'F S',
#   'team_title': 'Liverpool',
#   'npg': '3',
#   'npxG': '4.497195553034544',
#   'xGChain': '5.542443435639143',
#   'xGBuildup': '0.051715876907110214'},
#  {'id': '11094',
#   'player_name': 'Antony',
#   'games': '6',
#   'time': '499',
#   'goals': '3',
#   'xG': '1.4754690453410149',
#   'assists': '0',
#   'xA': '0.3073886949568987',
#   'shots': '20',
#   'key_passes': '7',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Manchester United',
#   'npg': '3',
#   'npxG': '1.4754690453410149',
#   'xGChain': '2.8844632655382156',
#   'xGBuildup': '1.1983138164505363'},
#  {'id': '314',
#   'player_name': 'Ilkay Gündogan',
#   'games': '9',
#   'time': '628',
#   'goals': '2',
#   'xG': '1.5031978413462639',
#   'assists': '1',
#   'xA': '1.8043835312128067',
#   'shots': '16',
#   'key_passes': '19',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Manchester City',
#   'npg': '2',
#   'npxG': '1.5031978413462639',
#   'xGChain': '5.676287740468979',
#   'xGBuildup': '3.5288837924599648'},
#  {'id': '447',
#   'player_name': 'Kevin De Bruyne',
#   'games': '11',
#   'time': '874',
#   'goals': '2',
#   'xG': '2.142825126647949',
#   'assists': '9',
#   'xA': '6.030883356928825',
#   'shots': '25',
#   'key_passes': '36',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Manchester City',
#   'npg': '2',
#   'npxG': '2.142825126647949',
#   'xGChain': '10.787080526351929',
#   'xGBuildup': '5.8211699873209'},
#  {'id': '531',
#   'player_name': 'Michail Antonio',
#   'games': '12',
#   'time': '525',
#   'goals': '2',
#   'xG': '2.1965922601521015',
#   'assists': '1',
#   'xA': '0.6456505432724953',
#   'shots': '13',
#   'key_passes': '6',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'West Ham',
#   'npg': '2',
#   'npxG': '2.1965922601521015',
#   'xGChain': '2.461606666445732',
#   'xGBuildup': '0.7416208665817976'},
#  {'id': '553',
#   'player_name': 'Anthony Martial',
#   'games': '3',
#   'time': '100',
#   'goals': '2',
#   'xG': '1.43720281124115',
#   'assists': '2',
#   'xA': '1.0848289132118225',
#   'shots': '2',
#   'key_passes': '3',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Manchester United',
#   'npg': '1',
#   'npxG': '0.6760339736938477',
#   'xGChain': '1.9010013937950134',
#   'xGBuildup': '0.1401385199278593'},
#  {'id': '643',
#   'player_name': 'Eric Dier',
#   'games': '12',
#   'time': '1074',
#   'goals': '2',
#   'xG': '0.3816608814522624',
#   'assists': '0',
#   'xA': '0.4878960847854614',
#   'shots': '8',
#   'key_passes': '2',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D',
#   'team_title': 'Tottenham',
#   'npg': '2',
#   'npxG': '0.3816608814522624',
#   'xGChain': '3.623551182448864',
#   'xGBuildup': '3.4960634633898735'},
#  {'id': '910',
#   'player_name': 'Harrison Reed',
#   'games': '12',
#   'time': '1006',
#   'goals': '2',
#   'xG': '0.9379809256643057',
#   'assists': '1',
#   'xA': '1.46766696870327',
#   'shots': '7',
#   'key_passes': '15',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Fulham',
#   'npg': '2',
#   'npxG': '0.9379809256643057',
#   'xGChain': '3.604057810269296',
#   'xGBuildup': '1.4067220259457827'},
#  {'id': '1228',
#   'player_name': 'Bruno Fernandes',
#   'games': '11',
#   'time': '990',
#   'goals': '2',
#   'xG': '2.1975530460476875',
#   'assists': '1',
#   'xA': '2.5504246847704053',
#   'shots': '23',
#   'key_passes': '28',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Manchester United',
#   'npg': '2',
#   'npxG': '2.1975530460476875',
#   'xGChain': '8.584716781973839',
#   'xGBuildup': '4.598519392311573'},
#  {'id': '1389',
#   'player_name': 'Jorginho',
#   'games': '11',
#   'time': '739',
#   'goals': '2',
#   'xG': '1.6125671733170748',
#   'assists': '0',
#   'xA': '0.21298488788306713',
#   'shots': '5',
#   'key_passes': '4',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Chelsea',
#   'npg': '0',
#   'npxG': '0.09022949822247028',
#   'xGChain': '3.6408216319978237',
#   'xGBuildup': '3.3376073203980923'},
#  {'id': '1679',
#   'player_name': 'Dominic Solanke',
#   'games': '10',
#   'time': '806',
#   'goals': '2',
#   'xG': '2.1988711804151535',
#   'assists': '3',
#   'xA': '1.281649224460125',
#   'shots': '18',
#   'key_passes': '6',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Bournemouth',
#   'npg': '2',
#   'npxG': '2.1988711804151535',
#   'xGChain': '3.578003950417042',
#   'xGBuildup': '0.3574897851794958'},
#  {'id': '1776',
#   'player_name': 'Jarrod Bowen',
#   'games': '12',
#   'time': '1078',
#   'goals': '2',
#   'xG': '4.475405998528004',
#   'assists': '0',
#   'xA': '1.5027342215180397',
#   'shots': '29',
#   'key_passes': '16',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F M',
#   'team_title': 'West Ham',
#   'npg': '1',
#   'npxG': '2.9530683057382703',
#   'xGChain': '4.641201024875045',
#   'xGBuildup': '0.6828236114233732'},
#  {'id': '2182',
#   'player_name': 'Jefferson Lerma',
#   'games': '12',
#   'time': '1080',
#   'goals': '2',
#   'xG': '1.1129679372534156',
#   'assists': '0',
#   'xA': '0.5520370975136757',
#   'shots': '12',
#   'key_passes': '2',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'D M',
#   'team_title': 'Bournemouth',
#   'npg': '2',
#   'npxG': '1.1129679372534156',
#   'xGChain': '2.233096608892083',
#   'xGBuildup': '1.5439662747085094'},
#  {'id': '2379',
#   'player_name': 'João Cancelo',
#   'games': '11',
#   'time': '926',
#   'goals': '2',
#   'xG': '0.31182725355029106',
#   'assists': '1',
#   'xA': '0.7366783991456032',
#   'shots': '10',
#   'key_passes': '9',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'D',
#   'team_title': 'Manchester City',
#   'npg': '2',
#   'npxG': '0.31182725355029106',
#   'xGChain': '6.073107115924358',
#   'xGBuildup': '5.482960864901543'},
#  {'id': '3635',
#   'player_name': 'Bernardo Silva',
#   'games': '11',
#   'time': '799',
#   'goals': '2',
#   'xG': '1.035807330161333',
#   'assists': '5',
#   'xA': '1.4053386431187391',
#   'shots': '11',
#   'key_passes': '15',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Manchester City',
#   'npg': '2',
#   'npxG': '1.035807330161333',
#   'xGChain': '7.690947510302067',
#   'xGBuildup': '5.681166864931583'},
#  {'id': '3697',
#   'player_name': 'Odsonne Edouard',
#   'games': '11',
#   'time': '708',
#   'goals': '2',
#   'xG': '1.9827646799385548',
#   'assists': '2',
#   'xA': '0.7834635525941849',
#   'shots': '14',
#   'key_passes': '7',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Crystal Palace',
#   'npg': '2',
#   'npxG': '1.9827646799385548',
#   'xGChain': '3.422319008037448',
#   'xGBuildup': '1.408418694511056'},
#  {'id': '5220',
#   'player_name': 'Kai Havertz',
#   'games': '10',
#   'time': '741',
#   'goals': '2',
#   'xG': '2.3453932106494904',
#   'assists': '0',
#   'xA': '0.3190794587135315',
#   'shots': '16',
#   'key_passes': '4',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Chelsea',
#   'npg': '2',
#   'npxG': '2.3453932106494904',
#   'xGChain': '4.032604783773422',
#   'xGBuildup': '1.513497669249773'},
#  {'id': '5221',
#   'player_name': 'Leon Bailey',
#   'games': '11',
#   'time': '698',
#   'goals': '2',
#   'xG': '1.5106154344975948',
#   'assists': '2',
#   'xA': '2.588031057268381',
#   'shots': '15',
#   'key_passes': '10',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Aston Villa',
#   'npg': '2',
#   'npxG': '1.5106154344975948',
#   'xGChain': '4.0250744223594666',
#   'xGBuildup': '0.586921751499176'},
#  {'id': '5232',
#   'player_name': 'Alexander Isak',
#   'games': '3',
#   'time': '248',
#   'goals': '2',
#   'xG': '2.440590262413025',
#   'assists': '0',
#   'xA': '0.17835214734077454',
#   'shots': '8',
#   'key_passes': '3',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F',
#   'team_title': 'Newcastle United',
#   'npg': '1',
#   'npxG': '1.6794214323163033',
#   'xGChain': '1.8473879620432854',
#   'xGBuildup': '0.06239278241991997'},
#  {'id': '5786',
#   'player_name': 'Yoane Wissa',
#   'games': '12',
#   'time': '445',
#   'goals': '2',
#   'xG': '1.9906353680416942',
#   'assists': '1',
#   'xA': '0.6783258691430092',
#   'shots': '13',
#   'key_passes': '2',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Brentford',
#   'npg': '2',
#   'npxG': '1.9906353680416942',
#   'xGChain': '3.863211240619421',
#   'xGBuildup': '1.917990319430828'},
#  {'id': '5956',
#   'player_name': 'Youri Tielemans',
#   'games': '12',
#   'time': '948',
#   'goals': '2',
#   'xG': '0.9528045989573002',
#   'assists': '1',
#   'xA': '1.8434029072523117',
#   'shots': '11',
#   'key_passes': '16',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Leicester',
#   'npg': '1',
#   'npxG': '0.19163576140999794',
#   'xGChain': '5.501036286354065',
#   'xGBuildup': '4.489010706543922'},
#  {'id': '6253',
#   'player_name': 'Gianluca Scamacca',
#   'games': '10',
#   'time': '569',
#   'goals': '2',
#   'xG': '2.1167661529034376',
#   'assists': '0',
#   'xA': '0.9975782837718725',
#   'shots': '20',
#   'key_passes': '10',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'West Ham',
#   'npg': '2',
#   'npxG': '2.1167661529034376',
#   'xGChain': '2.6771937664598227',
#   'xGBuildup': '0.1898102480918169'},
#  {'id': '6345',
#   'player_name': 'Jadon Sancho',
#   'games': '10',
#   'time': '737',
#   'goals': '2',
#   'xG': '1.1991688143461943',
#   'assists': '1',
#   'xA': '0.7173826433718204',
#   'shots': '7',
#   'key_passes': '14',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F M',
#   'team_title': 'Manchester United',
#   'npg': '2',
#   'npxG': '1.1991688143461943',
#   'xGChain': '3.680772228166461',
#   'xGBuildup': '2.2037903051823378'},
#  {'id': '6552',
#   'player_name': 'Bryan Mbeumo',
#   'games': '12',
#   'time': '920',
#   'goals': '2',
#   'xG': '2.611456284299493',
#   'assists': '0',
#   'xA': '1.3406967986375093',
#   'shots': '23',
#   'key_passes': '11',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F',
#   'team_title': 'Brentford',
#   'npg': '2',
#   'npxG': '2.611456284299493',
#   'xGChain': '5.228839946910739',
#   'xGBuildup': '1.7319536171853542'},
#  {'id': '6756',
#   'player_name': 'Dwight McNeil',
#   'games': '12',
#   'time': '575',
#   'goals': '2',
#   'xG': '0.9075209517031908',
#   'assists': '0',
#   'xA': '1.4263307712972164',
#   'shots': '9',
#   'key_passes': '8',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'D F M S',
#   'team_title': 'Everton',
#   'npg': '2',
#   'npxG': '0.9075209517031908',
#   'xGChain': '2.5619646217674017',
#   'xGBuildup': '1.1948903799057007'},
#  {'id': '6853',
#   'player_name': 'Rúben Neves',
#   'games': '11',
#   'time': '990',
#   'goals': '2',
#   'xG': '1.3409418696537614',
#   'assists': '0',
#   'xA': '0.34978197142481804',
#   'shots': '19',
#   'key_passes': '7',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'D M',
#   'team_title': 'Wolverhampton Wanderers',
#   'npg': '1',
#   'npxG': '0.5797730507329106',
#   'xGChain': '4.260968659073114',
#   'xGBuildup': '3.9190577305853367'},
#  {'id': '6888',
#   'player_name': 'William Saliba',
#   'games': '11',
#   'time': '990',
#   'goals': '2',
#   'xG': '0.25305715948343277',
#   'assists': '1',
#   'xA': '0.912389762699604',
#   'shots': '3',
#   'key_passes': '2',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'D',
#   'team_title': 'Arsenal',
#   'npg': '2',
#   'npxG': '0.25305715948343277',
#   'xGChain': '4.142438840121031',
#   'xGBuildup': '4.071100484579802'},
#  {'id': '7768',
#   'player_name': 'Mason Mount',
#   'games': '11',
#   'time': '820',
#   'goals': '2',
#   'xG': '1.6202681586146355',
#   'assists': '2',
#   'xA': '1.5270497668534517',
#   'shots': '18',
#   'key_passes': '16',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Chelsea',
#   'npg': '2',
#   'npxG': '1.6202681586146355',
#   'xGChain': '3.990141160786152',
#   'xGBuildup': '1.9123983066529036'},
#  {'id': '8291',
#   'player_name': 'Daniel Podence',
#   'games': '12',
#   'time': '865',
#   'goals': '2',
#   'xG': '2.009035561233759',
#   'assists': '0',
#   'xA': '1.4737432450056076',
#   'shots': '20',
#   'key_passes': '19',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Wolverhampton Wanderers',
#   'npg': '2',
#   'npxG': '2.009035561233759',
#   'xGChain': '4.941349893808365',
#   'xGBuildup': '1.7611061334609985'},
#  {'id': '8327',
#   'player_name': 'Bruno Guimarães',
#   'games': '9',
#   'time': '751',
#   'goals': '2',
#   'xG': '0.3954995535314083',
#   'assists': '2',
#   'xA': '1.5422694310545921',
#   'shots': '7',
#   'key_passes': '14',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Newcastle United',
#   'npg': '2',
#   'npxG': '0.3954995535314083',
#   'xGChain': '3.3934008311480284',
#   'xGBuildup': '2.8632748667150736'},
#  {'id': '8706',
#   'player_name': 'Eberechi Eze',
#   'games': '11',
#   'time': '930',
#   'goals': '2',
#   'xG': '1.7827393896877766',
#   'assists': '2',
#   'xA': '2.241882786154747',
#   'shots': '19',
#   'key_passes': '20',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Crystal Palace',
#   'npg': '2',
#   'npxG': '1.7827393896877766',
#   'xGChain': '4.407208425924182',
#   'xGBuildup': '2.2576392702758312'},
#  {'id': '8865',
#   'player_name': 'Ollie Watkins',
#   'games': '12',
#   'time': '1005',
#   'goals': '2',
#   'xG': '5.121251128613949',
#   'assists': '2',
#   'xA': '1.450724121183157',
#   'shots': '27',
#   'key_passes': '8',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Aston Villa',
#   'npg': '2',
#   'npxG': '5.121251128613949',
#   'xGChain': '7.544473962858319',
#   'xGBuildup': '2.3027529940009117'},
#  {'id': '9501',
#   'player_name': 'Fabio Carvalho',
#   'games': '10',
#   'time': '326',
#   'goals': '2',
#   'xG': '1.157909832894802',
#   'assists': '0',
#   'xA': '0.10462751239538193',
#   'shots': '11',
#   'key_passes': '1',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Liverpool',
#   'npg': '2',
#   'npxG': '1.157909832894802',
#   'xGChain': '1.3311937153339386',
#   'xGBuildup': '0.6484702676534653'},
#  {'id': '10405',
#   'player_name': 'Josh Dasilva',
#   'games': '12',
#   'time': '512',
#   'goals': '2',
#   'xG': '0.20753483846783638',
#   'assists': '0',
#   'xA': '0.48257267102599144',
#   'shots': '6',
#   'key_passes': '3',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Brentford',
#   'npg': '2',
#   'npxG': '0.20753483846783638',
#   'xGChain': '1.9386402610689402',
#   'xGBuildup': '1.68660076148808'},
#  {'id': '10715',
#   'player_name': 'João Palhinha',
#   'games': '11',
#   'time': '989',
#   'goals': '2',
#   'xG': '0.571815088391304',
#   'assists': '0',
#   'xA': '0',
#   'shots': '12',
#   'key_passes': '0',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Fulham',
#   'npg': '2',
#   'npxG': '0.571815088391304',
#   'xGChain': '2.3407359644770622',
#   'xGBuildup': '2.2400722671300173'},
#  {'id': '10760',
#   'player_name': 'Brennan Johnson',
#   'games': '12',
#   'time': '981',
#   'goals': '2',
#   'xG': '3.0050620697438717',
#   'assists': '0',
#   'xA': '1.0019658021628857',
#   'shots': '15',
#   'key_passes': '6',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Nottingham Forest',
#   'npg': '1',
#   'npxG': '1.4827243946492672',
#   'xGChain': '2.999979827553034',
#   'xGBuildup': '0.5152896270155907'},
#  {'id': '10766',
#   'player_name': 'Joe Ayodele-Aribo',
#   'games': '12',
#   'time': '825',
#   'goals': '2',
#   'xG': '1.9351601637899876',
#   'assists': '0',
#   'xA': '0.5579451080411673',
#   'shots': '11',
#   'key_passes': '7',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Southampton',
#   'npg': '2',
#   'npxG': '1.9351601637899876',
#   'xGChain': '3.0002885069698095',
#   'xGBuildup': '0.6180183365941048'},
#  {'id': '10846',
#   'player_name': 'Julián Álvarez',
#   'games': '9',
#   'time': '189',
#   'goals': '2',
#   'xG': '1.0813466310501099',
#   'assists': '0',
#   'xA': '0.5001745112240314',
#   'shots': '7',
#   'key_passes': '3',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Manchester City',
#   'npg': '2',
#   'npxG': '1.0813466310501099',
#   'xGChain': '2.8574235886335373',
#   'xGBuildup': '1.6299058441072702'},
#  {'id': '10866',
#   'player_name': 'Luis Sinisterra',
#   'games': '9',
#   'time': '464',
#   'goals': '2',
#   'xG': '1.0376011785119772',
#   'assists': '0',
#   'xA': '0.21222162432968616',
#   'shots': '10',
#   'key_passes': '4',
#   'yellow_cards': '1',
#   'red_cards': '1',
#   'position': 'M S',
#   'team_title': 'Leeds',
#   'npg': '2',
#   'npxG': '1.0376011785119772',
#   'xGChain': '2.7011044025421143',
#   'xGBuildup': '1.5669861808419228'},
#  {'id': '76',
#   'player_name': 'Fabian Schär',
#   'games': '11',
#   'time': '987',
#   'goals': '1',
#   'xG': '1.0436344221234322',
#   'assists': '0',
#   'xA': '0.2921486161649227',
#   'shots': '15',
#   'key_passes': '6',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'D',
#   'team_title': 'Newcastle United',
#   'npg': '1',
#   'npxG': '1.0436344221234322',
#   'xGChain': '2.0098243542015553',
#   'xGBuildup': '1.8062512911856174'},
#  {'id': '101',
#   'player_name': 'Allan Saint-Maximin',
#   'games': '5',
#   'time': '357',
#   'goals': '1',
#   'xG': '0.7863253206014633',
#   'assists': '2',
#   'xA': '1.2688706405460835',
#   'shots': '12',
#   'key_passes': '7',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Newcastle United',
#   'npg': '1',
#   'npxG': '0.7863253206014633',
#   'xGChain': '3.1641466692090034',
#   'xGBuildup': '1.2592085748910904'},
#  {'id': '318',
#   'player_name': 'Pierre-Emerick Aubameyang',
#   'games': '4',
#   'time': '222',
#   'goals': '1',
#   'xG': '0.22807497158646584',
#   'assists': '0',
#   'xA': '0.3109811767935753',
#   'shots': '4',
#   'key_passes': '3',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Chelsea',
#   'npg': '1',
#   'npxG': '0.22807497158646584',
#   'xGChain': '0.695957861840725',
#   'xGBuildup': '0.3181125372648239'},
#  {'id': '500',
#   'player_name': 'Alex Iwobi',
#   'games': '12',
#   'time': '1065',
#   'goals': '1',
#   'xG': '0.2349365446716547',
#   'assists': '5',
#   'xA': '2.1477534770965576',
#   'shots': '9',
#   'key_passes': '21',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Everton',
#   'npg': '1',
#   'npxG': '0.2349365446716547',
#   'xGChain': '3.556413434445858',
#   'xGBuildup': '1.597564671188593'},
#  {'id': '532',
#   'player_name': 'Cheikhou Kouyaté',
#   'games': '9',
#   'time': '497',
#   'goals': '1',
#   'xG': '0.17214820720255375',
#   'assists': '0',
#   'xA': '0.8150621205568314',
#   'shots': '5',
#   'key_passes': '5',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'D M S',
#   'team_title': 'Nottingham Forest',
#   'npg': '1',
#   'npxG': '0.17214820720255375',
#   'xGChain': '1.2654419597238302',
#   'xGBuildup': '1.0655491948127747'},
#  {'id': '620',
#   'player_name': 'Kelechi Iheanacho',
#   'games': '9',
#   'time': '178',
#   'goals': '1',
#   'xG': '0.7992085739970207',
#   'assists': '1',
#   'xA': '0.33397128246724606',
#   'shots': '8',
#   'key_passes': '7',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Leicester',
#   'npg': '1',
#   'npxG': '0.7992085739970207',
#   'xGChain': '1.1550285145640373',
#   'xGBuildup': '0.19525495544075966'},
#  {'id': '631',
#   'player_name': 'Ashley Young',
#   'games': '8',
#   'time': '605',
#   'goals': '1',
#   'xG': '0.13861909322440624',
#   'assists': '0',
#   'xA': '0.49145397171378136',
#   'shots': '5',
#   'key_passes': '9',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Aston Villa',
#   'npg': '1',
#   'npxG': '0.13861909322440624',
#   'xGChain': '3.366859219968319',
#   'xGBuildup': '2.7980068176984787'},
#  {'id': '652',
#   'player_name': 'Kieran Trippier',
#   'games': '12',
#   'time': '1073',
#   'goals': '1',
#   'xG': '0.3958027735352516',
#   'assists': '1',
#   'xA': '2.910325188189745',
#   'shots': '6',
#   'key_passes': '27',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'D',
#   'team_title': 'Newcastle United',
#   'npg': '1',
#   'npxG': '0.3958027735352516',
#   'xGChain': '3.5734571535140276',
#   'xGBuildup': '2.5716777462512255'},
#  {'id': '675',
#   'player_name': 'Jack Grealish',
#   'games': '6',
#   'time': '397',
#   'goals': '1',
#   'xG': '1.1086470484733582',
#   'assists': '0',
#   'xA': '1.4789116606116295',
#   'shots': '5',
#   'key_passes': '12',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Manchester City',
#   'npg': '1',
#   'npxG': '1.1086470484733582',
#   'xGChain': '4.236827097833157',
#   'xGBuildup': '2.072162691503763'},
#  {'id': '700',
#   'player_name': 'Willian',
#   'games': '5',
#   'time': '301',
#   'goals': '1',
#   'xG': '1.1435824520885944',
#   'assists': '1',
#   'xA': '0.949169147759676',
#   'shots': '6',
#   'key_passes': '9',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Fulham',
#   'npg': '1',
#   'npxG': '1.1435824520885944',
#   'xGChain': '2.7108848318457603',
#   'xGBuildup': '0.7558821365237236'},
#  {'id': '750',
#   'player_name': 'Riyad Mahrez',
#   'games': '9',
#   'time': '371',
#   'goals': '1',
#   'xG': '1.5185226751491427',
#   'assists': '0',
#   'xA': '0.2526927785947919',
#   'shots': '12',
#   'key_passes': '7',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Manchester City',
#   'npg': '1',
#   'npxG': '1.5185226751491427',
#   'xGChain': '3.92636176943779',
#   'xGBuildup': '2.4314131811261177'},
#  {'id': '755',
#   'player_name': 'Jamie Vardy',
#   'games': '12',
#   'time': '638',
#   'goals': '1',
#   'xG': '2.0083011258393526',
#   'assists': '4',
#   'xA': '0.6686337422579527',
#   'shots': '11',
#   'key_passes': '5',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Leicester',
#   'npg': '1',
#   'npxG': '2.0083011258393526',
#   'xGChain': '3.063775496557355',
#   'xGBuildup': '0.5180670414119959'},
#  {'id': '762',
#   'player_name': 'Demarai Gray',
#   'games': '12',
#   'time': '1043',
#   'goals': '1',
#   'xG': '2.01581671833992',
#   'assists': '0',
#   'xA': '1.1372926011681557',
#   'shots': '23',
#   'key_passes': '13',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F M',
#   'team_title': 'Everton',
#   'npg': '1',
#   'npxG': '2.01581671833992',
#   'xGChain': '3.850736640393734',
#   'xGBuildup': '1.1722839027643204'},
#  {'id': '782',
#   'player_name': 'Ben Chilwell',
#   'games': '8',
#   'time': '393',
#   'goals': '1',
#   'xG': '0.3777288869023323',
#   'assists': '1',
#   'xA': '0.11917553097009659',
#   'shots': '2',
#   'key_passes': '1',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Chelsea',
#   'npg': '1',
#   'npxG': '0.3777288869023323',
#   'xGChain': '1.012997955083847',
#   'xGBuildup': '0.9789943993091583'},
#  {'id': '833',
#   'player_name': 'Virgil van Dijk',
#   'games': '11',
#   'time': '990',
#   'goals': '1',
#   'xG': '1.0834892326965928',
#   'assists': '0',
#   'xA': '0.019994065165519714',
#   'shots': '12',
#   'key_passes': '1',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D',
#   'team_title': 'Liverpool',
#   'npg': '1',
#   'npxG': '1.0834892326965928',
#   'xGChain': '5.480187803506851',
#   'xGBuildup': '5.4503529369831085'},
#  {'id': '843',
#   'player_name': 'James Ward-Prowse',
#   'games': '12',
#   'time': '1080',
#   'goals': '1',
#   'xG': '0.4357357732951641',
#   'assists': '1',
#   'xA': '1.8930428884923458',
#   'shots': '10',
#   'key_passes': '20',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Southampton',
#   'npg': '1',
#   'npxG': '0.4357357732951641',
#   'xGChain': '2.6869620233774185',
#   'xGBuildup': '2.2762893699109554'},
#  {'id': '885',
#   'player_name': 'Kyle Walker-Peters',
#   'games': '11',
#   'time': '958',
#   'goals': '1',
#   'xG': '0.3979656659066677',
#   'assists': '0',
#   'xA': '1.0893075168132782',
#   'shots': '5',
#   'key_passes': '7',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'D',
#   'team_title': 'Southampton',
#   'npg': '1',
#   'npxG': '0.3979656659066677',
#   'xGChain': '3.089970014989376',
#   'xGBuildup': '2.283540948294103'},
#  {'id': '900',
#   'player_name': 'Adama Traoré',
#   'games': '9',
#   'time': '424',
#   'goals': '1',
#   'xG': '0.5782075375318527',
#   'assists': '0',
#   'xA': '0.5705661103129387',
#   'shots': '6',
#   'key_passes': '8',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Wolverhampton Wanderers',
#   'npg': '1',
#   'npxG': '0.5782075375318527',
#   'xGChain': '1.6856130976229906',
#   'xGBuildup': '0.5760740134865046'},
#  {'id': '922',
#   'player_name': 'Andreas Pereira',
#   'games': '12',
#   'time': '1014',
#   'goals': '1',
#   'xG': '1.326939002610743',
#   'assists': '4',
#   'xA': '2.0841932548210025',
#   'shots': '17',
#   'key_passes': '27',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Fulham',
#   'npg': '1',
#   'npxG': '1.326939002610743',
#   'xGChain': '3.6839600168168545',
#   'xGBuildup': '2.3706012573093176'},
#  {'id': '935',
#   'player_name': 'Kurt Zouma',
#   'games': '11',
#   'time': '990',
#   'goals': '1',
#   'xG': '0.910136166960001',
#   'assists': '0',
#   'xA': '0',
#   'shots': '8',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'D',
#   'team_title': 'West Ham',
#   'npg': '1',
#   'npxG': '0.910136166960001',
#   'xGChain': '1.2856971509754658',
#   'xGBuildup': '1.2856971509754658'},
#  {'id': '1376',
#   'player_name': 'Kalidou Koulibaly',
#   'games': '8',
#   'time': '662',
#   'goals': '1',
#   'xG': '0.2583279060199857',
#   'assists': '0',
#   'xA': '0.07862041145563126',
#   'shots': '7',
#   'key_passes': '2',
#   'yellow_cards': '1',
#   'red_cards': '1',
#   'position': 'D S',
#   'team_title': 'Chelsea',
#   'npg': '1',
#   'npxG': '0.2583279060199857',
#   'xGChain': '2.610561341047287',
#   'xGBuildup': '2.5126267075538635'},
#  {'id': '1654',
#   'player_name': 'Ben Mee',
#   'games': '11',
#   'time': '943',
#   'goals': '1',
#   'xG': '1.166271517984569',
#   'assists': '0',
#   'xA': '0',
#   'shots': '7',
#   'key_passes': '0',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D',
#   'team_title': 'Brentford',
#   'npg': '1',
#   'npxG': '1.166271517984569',
#   'xGChain': '2.053806707262993',
#   'xGBuildup': '2.014082297682762'},
#  {'id': '1791',
#   'player_name': 'Trent Alexander-Arnold',
#   'games': '11',
#   'time': '751',
#   'goals': '1',
#   'xG': '0.9012072160840034',
#   'assists': '0',
#   'xA': '2.3577809827402234',
#   'shots': '13',
#   'key_passes': '20',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Liverpool',
#   'npg': '1',
#   'npxG': '0.9012072160840034',
#   'xGChain': '5.797898907214403',
#   'xGBuildup': '3.743615049868822'},
#  {'id': '2203',
#   'player_name': 'Emiliano Buendía',
#   'games': '12',
#   'time': '500',
#   'goals': '1',
#   'xG': '1.7342034559696913',
#   'assists': '0',
#   'xA': '0.8994041122496128',
#   'shots': '12',
#   'key_passes': '12',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Aston Villa',
#   'npg': '1',
#   'npxG': '1.7342034559696913',
#   'xGChain': '3.2467804811894894',
#   'xGBuildup': '1.022030882537365'},
#  {'id': '2248',
#   'player_name': 'Casemiro',
#   'games': '8',
#   'time': '435',
#   'goals': '1',
#   'xG': '0.516057038679719',
#   'assists': '1',
#   'xA': '1.1663827188313007',
#   'shots': '7',
#   'key_passes': '5',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Manchester United',
#   'npg': '1',
#   'npxG': '0.516057038679719',
#   'xGChain': '3.171219103038311',
#   'xGBuildup': '1.5854017063975334'},
#  {'id': '2328',
#   'player_name': 'Thomas Partey',
#   'games': '8',
#   'time': '695',
#   'goals': '1',
#   'xG': '0.32422928884625435',
#   'assists': '0',
#   'xA': '0.2795211970806122',
#   'shots': '6',
#   'key_passes': '7',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Arsenal',
#   'npg': '1',
#   'npxG': '0.32422928884625435',
#   'xGChain': '3.9366548396646976',
#   'xGBuildup': '3.6050273813307285'},
#  {'id': '2335',
#   'player_name': 'Pablo Fornals',
#   'games': '11',
#   'time': '768',
#   'goals': '1',
#   'xG': '0.41142090409994125',
#   'assists': '0',
#   'xA': '0.32135745137929916',
#   'shots': '12',
#   'key_passes': '6',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'West Ham',
#   'npg': '1',
#   'npxG': '0.41142090409994125',
#   'xGChain': '2.4865545220673084',
#   'xGBuildup': '1.916930690407753'},
#  {'id': '2371',
#   'player_name': 'Cristiano Ronaldo',
#   'games': '8',
#   'time': '337',
#   'goals': '1',
#   'xG': '1.2051710039377213',
#   'assists': '0',
#   'xA': '0.3078584298491478',
#   'shots': '16',
#   'key_passes': '6',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Manchester United',
#   'npg': '1',
#   'npxG': '1.2051710039377213',
#   'xGChain': '2.062618300318718',
#   'xGBuildup': '0.9244475662708282'},
#  {'id': '2662',
#   'player_name': 'Christian Pulisic',
#   'games': '10',
#   'time': '256',
#   'goals': '1',
#   'xG': '0.883462306112051',
#   'assists': '1',
#   'xA': '0.25071396864950657',
#   'shots': '8',
#   'key_passes': '7',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Chelsea',
#   'npg': '1',
#   'npxG': '0.883462306112051',
#   'xGChain': '1.213172184303403',
#   'xGBuildup': '0.20703138411045074'},
#  {'id': '3203',
#   'player_name': 'Issa Diop',
#   'games': '5',
#   'time': '323',
#   'goals': '1',
#   'xG': '0.15752474963665009',
#   'assists': '0',
#   'xA': '0',
#   'shots': '1',
#   'key_passes': '0',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Fulham',
#   'npg': '1',
#   'npxG': '0.15752474963665009',
#   'xGChain': '1.171268917620182',
#   'xGBuildup': '1.171268917620182'},
#  {'id': '3585',
#   'player_name': 'Said Benrahma',
#   'games': '10',
#   'time': '498',
#   'goals': '1',
#   'xG': '1.7821792531758547',
#   'assists': '1',
#   'xA': '0.9203793499618769',
#   'shots': '22',
#   'key_passes': '12',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'West Ham',
#   'npg': '0',
#   'npxG': '1.0210104454308748',
#   'xGChain': '2.6903674080967903',
#   'xGBuildup': '1.3526843301951885'},
#  {'id': '3621',
#   'player_name': 'Neal Maupay',
#   'games': '7',
#   'time': '447',
#   'goals': '1',
#   'xG': '1.8535500392317772',
#   'assists': '0',
#   'xA': '0.25527650117874146',
#   'shots': '10',
#   'key_passes': '4',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Everton',
#   'npg': '1',
#   'npxG': '1.8535500392317772',
#   'xGChain': '1.9836901128292084',
#   'xGBuildup': '0.5895834788680077'},
#  {'id': '4419',
#   'player_name': 'Adam Armstrong',
#   'games': '12',
#   'time': '807',
#   'goals': '1',
#   'xG': '1.032244622707367',
#   'assists': '1',
#   'xA': '1.1812965534627438',
#   'shots': '12',
#   'key_passes': '8',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Southampton',
#   'npg': '1',
#   'npxG': '1.032244622707367',
#   'xGChain': '2.709584154188633',
#   'xGBuildup': '1.2244765348732471'},
#  {'id': '5086',
#   'player_name': 'Marc Roca',
#   'games': '11',
#   'time': '844',
#   'goals': '1',
#   'xG': '0.7119734920561314',
#   'assists': '0',
#   'xA': '0.2608890179544687',
#   'shots': '10',
#   'key_passes': '9',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Leeds',
#   'npg': '1',
#   'npxG': '0.7119734920561314',
#   'xGChain': '2.687697369605303',
#   'xGBuildup': '2.367388516664505'},
#  {'id': '5553',
#   'player_name': 'Declan Rice',
#   'games': '12',
#   'time': '1080',
#   'goals': '1',
#   'xG': '1.0896524954587221',
#   'assists': '1',
#   'xA': '0.8788817245513201',
#   'shots': '12',
#   'key_passes': '15',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'West Ham',
#   'npg': '1',
#   'npxG': '0.32848365791141987',
#   'xGChain': '3.196982594206929',
#   'xGBuildup': '2.455703491345048'},
#  {'id': '5555',
#   'player_name': 'Dominic Calvert-Lewin',
#   'games': '4',
#   'time': '190',
#   'goals': '1',
#   'xG': '0.42714156955480576',
#   'assists': '0',
#   'xA': '0',
#   'shots': '3',
#   'key_passes': '0',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Everton',
#   'npg': '1',
#   'npxG': '0.42714156955480576',
#   'xGChain': '0.39121612906455994',
#   'xGBuildup': '0.39121612906455994'},
#  {'id': '5590',
#   'player_name': 'Tosin Adarabioyo',
#   'games': '10',
#   'time': '900',
#   'goals': '1',
#   'xG': '0.1662689447402954',
#   'assists': '0',
#   'xA': '0.029784908518195152',
#   'shots': '4',
#   'key_passes': '1',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'D',
#   'team_title': 'Fulham',
#   'npg': '1',
#   'npxG': '0.1662689447402954',
#   'xGChain': '2.0325457081198692',
#   'xGBuildup': '2.0325457081198692'},
#  {'id': '5613',
#   'player_name': 'Gabriel',
#   'games': '11',
#   'time': '990',
#   'goals': '1',
#   'xG': '1.3328286539763212',
#   'assists': '0',
#   'xA': '0.09564077854156494',
#   'shots': '11',
#   'key_passes': '1',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D',
#   'team_title': 'Arsenal',
#   'npg': '1',
#   'npxG': '1.3328286539763212',
#   'xGChain': '3.4951914604753256',
#   'xGBuildup': '3.268085142597556'},
#  {'id': '5735',
#   'player_name': 'Jean-Philippe Mateta',
#   'games': '10',
#   'time': '224',
#   'goals': '1',
#   'xG': '1.102995753288269',
#   'assists': '0',
#   'xA': '0.2605995833873749',
#   'shots': '11',
#   'key_passes': '4',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Crystal Palace',
#   'npg': '1',
#   'npxG': '1.102995753288269',
#   'xGChain': '1.7259947955608368',
#   'xGBuildup': '0.5543886870145798'},
#  {'id': '6063',
#   'player_name': 'Jacob Murphy',
#   'games': '12',
#   'time': '381',
#   'goals': '1',
#   'xG': '1.021279215812683',
#   'assists': '0',
#   'xA': '0.29744579270482063',
#   'shots': '10',
#   'key_passes': '4',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Newcastle United',
#   'npg': '1',
#   'npxG': '1.021279215812683',
#   'xGChain': '3.441250303760171',
#   'xGBuildup': '2.174387773498893'},
#  {'id': '6108',
#   'player_name': 'Rodrigo Bentancur',
#   'games': '11',
#   'time': '980',
#   'goals': '1',
# ...
#   'xGBuildup': '0.16027545928955078'},
#  {'id': '10140',
#   'player_name': 'Hugo Bueno',
#   'games': '3',
#   'time': '181',
#   'goals': '0',
#   'xG': '0.02514027990400791',
#   'assists': '1',
#   'xA': '0.36497440189123154',
#   'shots': '1',
#   'key_passes': '3',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Wolverhampton Wanderers',
#   'npg': '0',
#   'npxG': '0.02514027990400791',
#   'xGChain': '0.9402913153171539',
#   'xGBuildup': '0.6180669367313385'},
#  {'id': '10291',
#   'player_name': 'Vitalii Mykolenko',
#   'games': '12',
#   'time': '1078',
#   'goals': '0',
#   'xG': '0.4940717173740268',
#   'assists': '0',
#   'xA': '0.30542990006506443',
#   'shots': '5',
#   'key_passes': '7',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'D',
#   'team_title': 'Everton',
#   'npg': '0',
#   'npxG': '0.4940717173740268',
#   'xGChain': '2.5358810126781464',
#   'xGBuildup': '1.8989342711865902'},
#  {'id': '10292',
#   'player_name': 'Nathan Patterson',
#   'games': '7',
#   'time': '630',
#   'goals': '0',
#   'xG': '0.4967552088201046',
#   'assists': '0',
#   'xA': '0.5483083724975586',
#   'shots': '5',
#   'key_passes': '2',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D',
#   'team_title': 'Everton',
#   'npg': '0',
#   'npxG': '0.4967552088201046',
#   'xGChain': '1.585647575557232',
#   'xGBuildup': '1.1593215223401785'},
#  {'id': '10293',
#   'player_name': 'Toti',
#   'games': '2',
#   'time': '180',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0.03923457860946655',
#   'shots': '0',
#   'key_passes': '1',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'D',
#   'team_title': 'Wolverhampton Wanderers',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0.1598995253443718',
#   'xGBuildup': '0.1598995253443718'},
#  {'id': '10552',
#   'player_name': 'Alejandro Garnacho',
#   'games': '1',
#   'time': '1',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Manchester United',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '10698',
#   'player_name': 'Malcolm Ebiowei',
#   'games': '2',
#   'time': '15',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Crystal Palace',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '10716',
#   'player_name': 'Manor Solomon',
#   'games': '1',
#   'time': '22',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Fulham',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '10718',
#   'player_name': 'Jay Stansfield',
#   'games': '3',
#   'time': '85',
#   'goals': '0',
#   'xG': '0.17301702499389648',
#   'assists': '0',
#   'xA': '0.058965012431144714',
#   'shots': '2',
#   'key_passes': '1',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Fulham',
#   'npg': '0',
#   'npxG': '0.17301702499389648',
#   'xGChain': '0.2319820374250412',
#   'xGBuildup': '0'},
#  {'id': '10719',
#   'player_name': 'Luke Harris',
#   'games': '1',
#   'time': '2',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Fulham',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '10723',
#   'player_name': 'Stefan Bajcetic',
#   'games': '1',
#   'time': '18',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Liverpool',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0.5863476395606995',
#   'xGBuildup': '0.5863476395606995'},
#  {'id': '10740',
#   'player_name': 'Jordan Zemura',
#   'games': '9',
#   'time': '610',
#   'goals': '0',
#   'xG': '0',
#   'assists': '1',
#   'xA': '0.9030280746519566',
#   'shots': '0',
#   'key_passes': '8',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D M S',
#   'team_title': 'Bournemouth',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '1.505041303113103',
#   'xGBuildup': '0.6204741206020117'},
#  {'id': '10741',
#   'player_name': 'Marcus Tavernier',
#   'games': '12',
#   'time': '1055',
#   'goals': '0',
#   'xG': '0.9605798088014126',
#   'assists': '0',
#   'xA': '0.6509614661335945',
#   'shots': '17',
#   'key_passes': '8',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D M',
#   'team_title': 'Bournemouth',
#   'npg': '0',
#   'npxG': '0.9605798088014126',
#   'xGChain': '2.153273828327656',
#   'xGBuildup': '0.9784275218844414'},
#  {'id': '10742',
#   'player_name': 'Ben Pearson',
#   'games': '4',
#   'time': '218',
#   'goals': '0',
#   'xG': '0.042054176330566406',
#   'assists': '0',
#   'xA': '0',
#   'shots': '1',
#   'key_passes': '0',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Bournemouth',
#   'npg': '0',
#   'npxG': '0.042054176330566406',
#   'xGChain': '0.06880305707454681',
#   'xGBuildup': '0.02674887701869011'},
#  {'id': '10745',
#   'player_name': 'Emiliano Marcondes',
#   'games': '1',
#   'time': '6',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Bournemouth',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '10749',
#   'player_name': 'Siriki Dembélé',
#   'games': '1',
#   'time': '6',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Bournemouth',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '10750',
#   'player_name': 'Rasmus Kristensen',
#   'games': '9',
#   'time': '792',
#   'goals': '0',
#   'xG': '0.21898849122226238',
#   'assists': '0',
#   'xA': '0.5226096361875534',
#   'shots': '2',
#   'key_passes': '3',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'D',
#   'team_title': 'Leeds',
#   'npg': '0',
#   'npxG': '0.21898849122226238',
#   'xGChain': '2.089885137975216',
#   'xGBuildup': '1.5672754645347595'},
#  {'id': '10755',
#   'player_name': 'Joseph Hodge',
#   'games': '3',
#   'time': '70',
#   'goals': '0',
#   'xG': '0.09458642452955246',
#   'assists': '0',
#   'xA': '0',
#   'shots': '1',
#   'key_passes': '0',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Wolverhampton Wanderers',
#   'npg': '0',
#   'npxG': '0.09458642452955246',
#   'xGChain': '0.09458642452955246',
#   'xGBuildup': '0'},
#  {'id': '10756',
#   'player_name': 'Joe Worrall',
#   'games': '9',
#   'time': '593',
#   'goals': '0',
#   'xG': '0.08542998135089874',
#   'assists': '0',
#   'xA': '0.3944849669933319',
#   'shots': '1',
#   'key_passes': '2',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Nottingham Forest',
#   'npg': '0',
#   'npxG': '0.08542998135089874',
#   'xGChain': '1.0097088888287544',
#   'xGBuildup': '0.9909566342830658'},
#  {'id': '10757',
#   'player_name': 'Scott McKenna',
#   'games': '12',
#   'time': '1080',
#   'goals': '0',
#   'xG': '0.0726305115967989',
#   'assists': '0',
#   'xA': '0.4498777724802494',
#   'shots': '2',
#   'key_passes': '6',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'D',
#   'team_title': 'Nottingham Forest',
#   'npg': '0',
#   'npxG': '0.0726305115967989',
#   'xGChain': '2.26968552172184',
#   'xGBuildup': '1.8675250709056854'},
#  {'id': '10758',
#   'player_name': 'Harry Toffolo',
#   'games': '8',
#   'time': '577',
#   'goals': '0',
#   'xG': '0.09923675656318665',
#   'assists': '0',
#   'xA': '0.2554265037178993',
#   'shots': '2',
#   'key_passes': '3',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'D M S',
#   'team_title': 'Nottingham Forest',
#   'npg': '0',
#   'npxG': '0.09923675656318665',
#   'xGChain': '1.031295981258154',
#   'xGBuildup': '0.8592260088771582'},
#  {'id': '10761',
#   'player_name': 'Alex Mighten',
#   'games': '1',
#   'time': '5',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Nottingham Forest',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '10764',
#   'player_name': 'Djed Spence',
#   'games': '3',
#   'time': '3',
#   'goals': '0',
#   'xG': '0.11410751938819885',
#   'assists': '0',
#   'xA': '0',
#   'shots': '1',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Tottenham',
#   'npg': '0',
#   'npxG': '0.11410751938819885',
#   'xGChain': '0.11410751938819885',
#   'xGBuildup': '0'},
#  {'id': '10765',
#   'player_name': 'Gavin Bazunu',
#   'games': '12',
#   'time': '1080',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0.04283760115504265',
#   'shots': '0',
#   'key_passes': '1',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'GK',
#   'team_title': 'Southampton',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '1.2228890620172024',
#   'xGBuildup': '1.1800514571368694'},
#  {'id': '10802',
#   'player_name': 'Lisandro Martínez',
#   'games': '11',
#   'time': '943',
#   'goals': '0',
#   'xG': '0.07725168764591217',
#   'assists': '0',
#   'xA': '0',
#   'shots': '3',
#   'key_passes': '0',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'D',
#   'team_title': 'Manchester United',
#   'npg': '0',
#   'npxG': '0.07725168764591217',
#   'xGChain': '3.087947480380535',
#   'xGBuildup': '3.07444616407156'},
#  {'id': '10803',
#   'player_name': 'Tyrell Malacia',
#   'games': '7',
#   'time': '449',
#   'goals': '0',
#   'xG': '0.014477662742137909',
#   'assists': '0',
#   'xA': '0',
#   'shots': '1',
#   'key_passes': '0',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Manchester United',
#   'npg': '0',
#   'npxG': '0.014477662742137909',
#   'xGChain': '1.11141587048769',
#   'xGBuildup': '1.096938207745552'},
#  {'id': '10804',
#   'player_name': 'Deniz Undav',
#   'games': '6',
#   'time': '46',
#   'goals': '0',
#   'xG': '0.5237329751253128',
#   'assists': '0',
#   'xA': '0.20884139649569988',
#   'shots': '4',
#   'key_passes': '3',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Brighton',
#   'npg': '0',
#   'npxG': '0.5237329751253128',
#   'xGChain': '1.2023774962872267',
#   'xGBuildup': '0.6709929704666138'},
#  {'id': '10805',
#   'player_name': 'Levi Colwill',
#   'games': '2',
#   'time': '9',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Brighton',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '10806',
#   'player_name': 'Kaoru Mitoma',
#   'games': '7',
#   'time': '135',
#   'goals': '0',
#   'xG': '0.37549740076065063',
#   'assists': '0',
#   'xA': '1.154114492237568',
#   'shots': '2',
#   'key_passes': '6',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Brighton',
#   'npg': '0',
#   'npxG': '0.37549740076065063',
#   'xGChain': '2.4233932495117188',
#   'xGBuildup': '0.9388176873326302'},
#  {'id': '10807',
#   'player_name': 'Jan Paul van Hecke',
#   'games': '1',
#   'time': '1',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Brighton',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '10809',
#   'player_name': 'Keane Lewis-Potter',
#   'games': '5',
#   'time': '208',
#   'goals': '0',
#   'xG': '0.6462182961404324',
#   'assists': '1',
#   'xA': '0.9775039330124855',
#   'shots': '6',
#   'key_passes': '4',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Brentford',
#   'npg': '0',
#   'npxG': '0.6462182961404324',
#   'xGChain': '0.6896901801228523',
#   'xGBuildup': '0.048701029270887375'},
#  {'id': '10845',
#   'player_name': 'Flynn Downes',
#   'games': '4',
#   'time': '168',
#   'goals': '0',
#   'xG': '0.1499457061290741',
#   'assists': '0',
#   'xA': '0',
#   'shots': '2',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'West Ham',
#   'npg': '0',
#   'npxG': '0.1499457061290741',
#   'xGChain': '0.5710557252168655',
#   'xGBuildup': '0.42111001908779144'},
#  {'id': '10847',
#   'player_name': 'Rico Lewis',
#   'games': '3',
#   'time': '28',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Manchester City',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '10864',
#   'player_name': 'Marcos Senesi',
#   'games': '9',
#   'time': '672',
#   'goals': '0',
#   'xG': '0.09617077559232712',
#   'assists': '0',
#   'xA': '0.12307147681713104',
#   'shots': '1',
#   'key_passes': '2',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Bournemouth',
#   'npg': '0',
#   'npxG': '0.09617077559232712',
#   'xGChain': '0.5555413085967302',
#   'xGBuildup': '0.4324698355048895'},
#  {'id': '10865',
#   'player_name': 'Jamal Lowe',
#   'games': '1',
#   'time': '1',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Bournemouth',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '10997',
#   'player_name': 'Bobby Clark',
#   'games': '1',
#   'time': '5',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Liverpool',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '11000',
#   'player_name': 'Matheus Nunes',
#   'games': '10',
#   'time': '824',
#   'goals': '0',
#   'xG': '1.0751876384019852',
#   'assists': '1',
#   'xA': '1.1658550798892975',
#   'shots': '14',
#   'key_passes': '11',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Wolverhampton Wanderers',
#   'npg': '0',
#   'npxG': '1.0751876384019852',
#   'xGChain': '2.735894575715065',
#   'xGBuildup': '1.1660209223628044'},
#  {'id': '11003',
#   'player_name': 'Ryan Yates',
#   'games': '10',
#   'time': '763',
#   'goals': '0',
#   'xG': '1.2132852710783482',
#   'assists': '1',
#   'xA': '0.5011679902672768',
#   'shots': '16',
#   'key_passes': '3',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Nottingham Forest',
#   'npg': '0',
#   'npxG': '1.2132852710783482',
#   'xGChain': '1.3744574822485447',
#   'xGBuildup': '0.3547944128513336'},
#  {'id': '11034',
#   'player_name': 'Owen Bevan',
#   'games': '1',
#   'time': '6',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Bournemouth',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '11035',
#   'player_name': 'Marquinhos',
#   'games': '1',
#   'time': '1',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Arsenal',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '11078',
#   'player_name': 'Juan Larios',
#   'games': '4',
#   'time': '111',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Southampton',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0.07834596186876297',
#   'xGBuildup': '0.07834596186876297'},
#  {'id': '11132',
#   'player_name': 'Ethan Nwaneri',
#   'games': '1',
#   'time': '1',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Arsenal',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'}]

# %%
async def league_results():
    async with aiohttp.ClientSession() as session:
        understat = Understat(session)
        fixtures = await understat.get_league_results(
            "epl",
            2021
        )
        return(json.dumps(fixtures))

games = asyncio.run(league_results())
games = json.loads(games)
games = list(games)

# %%
#619 aguero
async def player_data():
    async with aiohttp.ClientSession() as session:
        understat = Understat(session)
        grouped_stats = await understat.get_player_grouped_stats(8260)
        return(json.dumps(grouped_stats))

stats = asyncio.run(player_data())
stats = json.loads(stats)

# %%
stats.keys()
# Out:
# dict_keys(['season', 'position', 'situation', 'shotZones', 'shotTypes'])

# %%
df_season = pd.DataFrame(stats["season"])
df_situation = pd.DataFrame(stats["situation"])
df_shotzones = pd.DataFrame(stats["shotZones"])
df_shotypes = pd.DataFrame(stats["shotTypes"])

# %%
df_season
# Out:
#   position games goals shots  time                  xG assists  \
# 0       FW    11    17    47   941  11.791812658309937       3
# 1       FW    24    22    80  1917   17.03095668926835       7
# 2       FW    28    27    92  2416  23.598482109606266       6
# 3      Sub    15    13    33  1061   8.889345575124025       2
#
#                    xA key_passes season               team yellow red npg  \
# 0  2.7509437054395676         11   2022    Manchester City      0   0  15
# 1    5.89400115981698         23   2021  Borussia Dortmund      3   0  16
# 2   4.035449907183647         27   2020  Borussia Dortmund      2   0  25
# 3  1.5264748334884644          9   2019  Borussia Dortmund      0   0  13
#
#                  npxG             xGChain           xGBuildup
# 0   10.26947483420372  11.118985623121262  0.7943455772474408
# 1  12.484377015382051  19.772439118474722  4.2647324707359076
# 2  20.567375369369984  27.197274826467037   5.896184146404266
# 3   8.889345575124025  11.366184580139816  2.9849864905700088

# %%
goals = df_season.iloc[0]["goals"]
assists = df_season.iloc[0]["assists"]
xg = df_season.iloc[0]["xG"]
xa = df_season.iloc[0]["xA"]
key_passes = df_season.iloc[0]["key_passes"]
xg_chain = df_season.iloc[0]["xGChain"]
xg_buildup = df_season.iloc[0]["xGBuildup"]

basic_stats = [goals, assists, key_passes]
advanced_stats = [xg, xa,xg_chain, xg_buildup]

basic_player_stats = pd.DataFrame(zip(basic_stats)).T
basic_player_stats.columns = ["Goals", "Assists", "Key Passes"]

advanced_player_stats = pd.DataFrame(zip(advanced_stats)).T
advanced_player_stats.columns = ["xG", "xA", "Key xGChain", "xGBuildup"]

# %%
advanced_player_stats
# Out:
#                    xG                  xA         Key xGChain  \
# 0  11.791812658309937  2.7509437054395676  11.118985623121262
#
#             xGBuildup
# 0  0.7943455772474408

# %%
fig = plt.figure()
# Use GridSpec for customising layout
gs = fig.add_gridspec(nrows=2, ncols=2)
# Add an empty axes that occupied the whole first row
ax1 = fig.add_subplot(gs[0, 0:12])
# Add two empty axes that occupied the remaining grid
ax2 = fig.add_subplot(gs[1, 0])
ax3 = fig.add_subplot(gs[1, 1])

# %%
# Set canvas background color the same as axes
plt.rc('figure', facecolor='w')

# set constrianed_layout as True to avoid axes overlap
fig = plt.figure(figsize=(10,12), dpi=300, constrained_layout=True)

# Use GridSpec for customising layout
gs = fig.add_gridspec(nrows=5, ncols=5)

# Set up a empty axes that occupied 2 rows and 10 cols in the grid for text
axText = fig.add_subplot(gs[0:1, :])

name = 'Erling Halaand'
team = 'Manchester City'
season = '2022-2023'

axText.annotate(name, (0.5, 0.83),
                xycoords='axes fraction', va='center', ha='center',fontsize=20)
axText.annotate(team, (0.5, 0.5),
                xycoords='axes fraction', va='center', ha='center',fontsize=20)
axText.annotate(season, (0.5, 0.17),
                xycoords='axes fraction', va='center', ha='center',fontsize=20)
axText.get_xaxis().set_visible(False)
axText.get_yaxis().set_visible(False)

# Add a color bar on top of axText, using figure coordinates 
axInlet = fig.add_axes([0.9, 0.97, 0.08, 0.01], frameon=True)
axInlet.annotate('I am ax2', (0.5, 0.5),
                 xycoords='axes fraction', va='center', ha='center')
axInlet.get_xaxis().set_visible(False)
axInlet.get_yaxis().set_visible(False)



# Set up a empty axes that occupied 2 rows and 10 cols in the grid for text
axText = fig.add_subplot(gs[1:4, 0:2])
axText.annotate('left', (0.5, 0.5),
                xycoords='axes fraction', va='center', ha='center')
axText.get_xaxis().set_visible(False)
axText.get_yaxis().set_visible(False)

# Set up a empty axes that occupied 2 rows and 10 cols in the grid for text


axText = fig.add_subplot(gs[1:4, 2:5])



the_table = ax.table(cellText=cell_text,
                      
                      colLabels=columns,
                      loc='top')
plt.table(the_table)
axText.annotate('right', (0.5, 0.5),
                xycoords='axes fraction', va='center', ha='center')
axText.get_xaxis().set_visible(False)
axText.get_yaxis().set_visible(False)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_28852/1772934349.py in <module>
#      44
#      45 axText = fig.add_subplot(gs[1:4, 2:5])
# ---> 46 plt.table(basic_player_stats)
#      47 axText.annotate('right', (0.5, 0.5),
#      48                 xycoords='axes fraction', va='center', ha='center')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in table(cellText, cellColours, cellLoc, colWidths, rowLabels, rowColours, rowLoc, colLabels, colColours, colLoc, loc, bbox, edges, **kwargs)
#    3175         colLoc='center', loc='bottom', bbox=None, edges='closed',
#    3176         **kwargs):
# -> 3177     return gca().table(
#    3178         cellText=cellText, cellColours=cellColours, cellLoc=cellLoc,
#    3179         colWidths=colWidths, rowLabels=rowLabels,
#
# ~\anaconda3\lib\site-packages\matplotlib\table.py in table(ax, cellText, cellColours, cellLoc, colWidths, rowLabels, rowColours, rowLoc, colLabels, colColours, colLoc, loc, bbox, edges, **kwargs)
#     739
#     740     rows = len(cellText)
# --> 741     cols = len(cellText[0])
#     742     for row in cellText:
#     743         if len(row) != cols:
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 0

# %%
for i, city in enumerate(cityList):
    ax = fig.add_subplot(gs[i+2, 0:9], ylim=(-30, 30))
    
    df_tmp = df.loc[df['City'] == city]
    # color scheme
    colors = cm.RdYlBu_r(df_tmp.max_tmp_day / max(df_tmp.max_tmp_day))
    ax.bar(df_tmp.Date, df_tmp.max_tmp_day - mean_temp, label='_1', color=colors,
           width=0.7, align="edge")
    
    # annotation for highest temp.
    highDate = df_tmp.loc[df_tmp['max_tmp_day'] == max(df_tmp.max_tmp_day)].Date
    highTemp = max(df_tmp.max_tmp_day) - mean_temp
    ax.annotate("Highest Temp.{}$^\circ$C\n{}".format(max(df_tmp.max_tmp_day), str(highDate)[-36:-26]),
                xy=(highDate, highTemp), xycoords='data',
                xytext=(highDate+timedelta(days=10), highTemp+5), textcoords='data',
                size=6,
                color='#e3e3e3',
                arrowprops=dict(arrowstyle="->",
                                connectionstyle="arc3, rad=.3",
                                color='#e3e3e3')
               )
    # annotation for lowest temp.
    lowDate = df_tmp.loc[df_tmp['max_tmp_day'] == min(df_tmp.max_tmp_day)].Date
    lowTemp = min(df_tmp.max_tmp_day) - mean_temp
    ax.annotate("Lowest Temp.{}$^\circ$C\n{}".format(min(df_tmp.max_tmp_day), str(lowDate)[-36:-26]),
                xy=(lowDate, lowTemp), xycoords='data',
                xytext=(lowDate-timedelta(days=20), lowTemp-30), textcoords='data',
                size=6,
                color='#e3e3e3',
                arrowprops=dict(arrowstyle="->",
                                connectionstyle="arc3, rad=.3",
                                color='#e3e3e3')
               )
    
    # customise axes
    ax.spines['bottom'].set_color(None)  
    ax.spines['right'].set_color(None)  
    ax.spines['left'].set_color(None)  
    ax.spines['top'].set_color(None) 
    ax.get_xaxis().set_ticks([])
    ax.get_yaxis().set_ticks([])
    ax.set_ylabel(city.title(), rotation=0, color='#e3e3e3', fontsize=10, fontweight='bold')
